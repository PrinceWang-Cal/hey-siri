# %%
#import dependencies
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import random
import string

# %%
G = nx.Graph()
s = 1e8
verdexList = []
verdexList.append('SabrinaSiriPrince')
for _ in range(49):
    verdexList.append(''.join([random.choice(string.ascii_letters + string.digits) for n in range(5)]))
    
home = []
home.append(verdexList[2])
home.extend(verdexList[4:11])
home.extend(verdexList[17:23])


G.add_edge(0, 1, weight=8.4736529 * s)
G.add_edge(0, 2, weight=7.712635873 * s)
G.add_edge(0, 3, weight=11.5737135723 * s)
G.add_edge(1, 3, weight= 6.281657 * s)
G.add_edge(1, 2, weight= 5.4585905874* s)
G.add_edge(2, 3, weight= 9.86536235* s)

G.add_edge(1, 4, weight= 2.7215624* s)
G.add_edge(1, 12, weight= 12.65274191* s)
G.add_edge(12, 5, weight= 9.87356120* s)
G.add_edge(1, 6, weight= 3.81075436892* s)
G.add_edge(1, 13, weight= 9.7251086765* s)
G.add_edge(13, 7, weight= 7.717365973* s)
G.add_edge(1, 14, weight= 6.871965736* s)
G.add_edge(14, 8, weight= 5.71968356342* s)
G.add_edge(1, 9, weight= 11.56187594287* s)
G.add_edge(1, 15, weight= 13.8125746873* s)
G.add_edge(15, 16, weight= 10.6215769734* s)
G.add_edge(16, 10, weight= 6.587618639* s)
G.add_edge(1, 11, weight= 7.6258726950* s)

G.add_edge(2, 17, weight= 15.8932460345* s)
G.add_edge(17, 18, weight= 10.7126524753* s)
G.add_edge(17, 19, weight= 12.3651386310* s)
G.add_edge(17, 20, weight= 15.975216570* s)
G.add_edge(17, 21, weight= 17.15684713987* s)
G.add_edge(17, 22, weight= 17.513796593726* s)
G.add_edge(17, 23, weight= 6.1753465634* s)
G.add_edge(18, 19, weight= 3.7156487625* s)
G.add_edge(19, 20, weight= 9.7126726524* s)
G.add_edge(20, 21, weight= 3.72165834695* s)
G.add_edge(21, 22, weight= 5.712985210* s)
G.add_edge(22, 23, weight= 9.47275697323* s)

G.add_edge(3, 24, weight= 8.1136589726* s)
G.add_edge(3, 26, weight= 11.076190345* s)
G.add_edge(3, 25, weight= 7.15326902* s)
G.add_edge(24, 26, weight= 6.02387508346* s)
G.add_edge(24, 25, weight= 5.1893275936* s)
G.add_edge(25, 26, weight= 9.18375209105* s)

G.add_edge(24, 27, weight= 8.12915705* s)
G.add_edge(24, 28, weight= 11.038701* s)
G.add_edge(24, 29, weight= 7.18952703867* s)
G.add_edge(27, 29, weight= 6.10918525046* s)
G.add_edge(27, 28, weight= 5.133526476* s)
G.add_edge(28, 29, weight= 9.13658326457* s)

G.add_edge(25, 30, weight= 8.13436485682* s)
G.add_edge(25, 31, weight= 11.1575875275* s)
G.add_edge(25, 32, weight= 7.257752878* s)
G.add_edge(30, 32, weight= 6.1578378687* s)
G.add_edge(30, 31, weight= 5.1344875278* s)
G.add_edge(31, 32, weight= 9.178767669* s)

G.add_edge(26, 33, weight= 8.1564868965* s)
G.add_edge(26, 34, weight= 11.0548658* s)
G.add_edge(26, 35, weight= 7.175858258* s)
G.add_edge(33, 35, weight= 6.05278587* s)
G.add_edge(33, 34, weight= 5.175468545* s)
G.add_edge(34, 35, weight= 9.0584684* s)

G.add_edge(26, 33, weight= 8.1564868965* s)
G.add_edge(26, 34, weight= 11.0548658* s)
G.add_edge(26, 35, weight= 7.175858258* s)
G.add_edge(33, 35, weight= 6.05278587* s)
G.add_edge(33, 34, weight= 5.175468545* s)
G.add_edge(34, 35, weight= 9.0584684* s)

G.add_edge(27, 36, weight= 8.1548268* s)
G.add_edge(27, 37, weight= 11.0187867* s)
G.add_edge(27, 38, weight= 7.16546846* s)
G.add_edge(36, 38, weight= 6.0435643734* s)
G.add_edge(36, 37, weight= 5.13568769* s)
G.add_edge(37, 38, weight= 9.04254766* s)

G.add_edge(28, 39, weight= 8.17868937* s)
G.add_edge(28, 40, weight= 11.07586846* s)
G.add_edge(28, 41, weight= 7.1786785* s)
G.add_edge(39, 41, weight= 6.067528* s)
G.add_edge(39, 40, weight= 5.1674524* s)
G.add_edge(40, 41, weight= 9.04588754* s)

G.add_edge(30, 42, weight= 8.054845548* s)
G.add_edge(30, 43, weight= 11.175784* s)
G.add_edge(30, 44, weight= 7.056587524* s)
G.add_edge(42, 44, weight= 6.07857858* s)
G.add_edge(42, 43, weight= 5.16888888* s)
G.add_edge(43, 44, weight= 9.066667676* s)

G.add_edge(30, 42, weight= 8.054845548* s)
G.add_edge(30, 43, weight= 11.175784* s)
G.add_edge(30, 44, weight= 7.056587524* s)
G.add_edge(42, 44, weight= 6.07857858* s)
G.add_edge(42, 43, weight= 5.16888888* s)
G.add_edge(43, 44, weight= 9.066667676* s)

G.add_edge(32, 45, weight= 8.1487465* s)
G.add_edge(32, 46, weight= 11.05688659* s)
G.add_edge(32, 47, weight= 7.04748465* s)
G.add_edge(45, 47, weight= 6.0484561265* s)
G.add_edge(45, 46, weight= 5.14987952* s)
G.add_edge(46, 47, weight= 9.1587895* s)

home.extend(verdexList[36:47])
print(len(home))
# Out:
# 25

# %%
nx.draw(G)
plt.show()

# %%
def graph_to_matrix(input_graph, weight_low, weight_high, randomize):
    
    #compute number of nodes in the graph
    node_count = input_graph.number_of_nodes()
    
    #convert graph into adjacency list formate
    graph_adjlst = nx.generate_adjlist(input_graph)
    
    #Create a nxn matrix of zero entries where n is node count
    output = np.zeros((node_count, node_count))
    
    
    for line in graph_adjlst:
        splitted_line = line.split(" ")
        row_num = int(splitted_line[0])
        output.itemset((row_num, row_num), 0)
        splitted_line = splitted_line[1:]
        for col_num in splitted_line:
            col_num = int(col_num)
            
            if randomize:
                weight = np.random.randint(low = weight_low, high = weight_high)
            else:
                weight = 1
                
            output.itemset((row_num, col_num), weight)
            output.itemset((col_num, row_num), weight)
    if randomize == False:
        for (u, v, d) in G.edges(data=True):
            output.itemset((u, v), round(d['weight'], 5))
            output.itemset((v, u), round(d['weight'], 5))
    return output

# %%
new_graph = graph_to_matrix(G, 5, 10, False)

# %%
def matrix_to_input(mat):
    mat_shape = mat.shape
    row_num = mat_shape[0]
    col_num = mat_shape[1]
    output = ""
    
    #convert matrix into an n-dimension array to iterate through
#     mat_ndarray = mat.A
    
    for row in mat:
#         count = 0
        for entry in row:
            if entry == 0:
                output += " x  "
            else:
                num_str = str(entry)
                output += " " + num_str
        output += "\n"
    return output

# %%
print(matrix_to_input(new_graph))
# Out:
#  x   847365290.0 771263587.3 1157371357.23 x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x
#  847365290.0 x   545859058.74 628165700.0 272156240.0 x   381075436.892 x   x   1156187594.287 x   762587269.5 1265274191.0 972510867.65 687196573.6 1381257468.73 x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x
#  771263587.3 545859058.74 x   986536235.0 x   x   x   x   x   x   x   x   x   x   x   x   x   1589324603.45 x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x
#  1157371357.23 628165700.0 986536235.0 x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   811365897.26 715326902.0 1107619034.5 x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x   x
# ...
